# %%
a = float(input("enter a number"))
if a % 2 == 0:
    print(a , " is an even number")
else:
    print(a , " is an odd number")
# Out:
# enter a number 5
# 5.0  is an odd number

# %%
a = float(input("enter a number"))
if a%15 == 0:
    print("hello")
else:
    print("bye")
# Out:
# enter a number 60
# hello

# %%
a = float(input("enter a number"))
if a%7==0 or a%9==0:
    print("hello")
else:
    print("bye")
# Out:
# enter a number 18
# hello

# %%
# GRADE SYSTEM
a = int(input("enter marks to find grade"))
if a<=100 and a >=90:
    print("A")
elif a<=89 and a >=80:
    print("B")
elif a<=79 and a >=70:
    print("C")
elif a<=69 and a >=60:
    print("D")
elif a<=59:
    print("Failed")
else:
    print("Enter valid input")
# Out:
# enter marks to find grade 56
# Failed

# %%
a = int(input("Enter a number"))
b = int(input("Enter a number"))
c = int(input("Enter a number"))
if a>b:
    if a>c:
        print(a , " is the greatest num")
    else:
        print(c , " is the greatest num")
else:
    if b>c:
        print(b , " is the greatest num")
    else:
        print(c , " is the greatest num")
# Out:
# Enter a number 1
# Enter a number 3
# Enter a number 2
# 3  is the greatest num

# %%
a = int(input("enter year"))
if a%4==0:
    if a%400 == 0 or a%100!=0:
        print("leap")
    else:
        print("not")
else:
    print("not")
# Out:
# enter year 450
# not

# %%
for i in range(1,11):
    if i%2==0:
        print(f"{i}--is even")
    else:
        print(f"{i}--is odd")
# Out:
# 1--is odd
# 2--is even
# 3--is odd
# 4--is even
# 5--is odd
# 6--is even
# 7--is odd
# 8--is even
# 9--is odd
# 10--is even

# %%
for i in range(1,51):
    if i%3==0 or i%5==0:
        print(i , end = " ")
# Out:
# 3 5 6 9 10 12 15 18 20 21 24 25 27 30 33 35 36 39 40 42 45 48 50

# %%
a = int(input("enter a number"))
for i in range(10,0,-1):
    print(f"{a} * {i} = {a*i}")
# Out:
# enter a number 7
# 7 * 10 = 70
# 7 * 9 = 63
# 7 * 8 = 56
# 7 * 7 = 49
# 7 * 6 = 42
# 7 * 5 = 35
# 7 * 4 = 28
# 7 * 3 = 21
# 7 * 2 = 14
# 7 * 1 = 7

# %%
s=0
c=0
for i in range (1,5):
    a = int(input("enter number"))
    s+=a
    c+=1
print(f"total marks {s}")
print(f"average marks {s/c}")
# Out:
# enter number 10
# enter number 20
# enter number 30
# enter number 40
# total marks 100
# average marks 25.0

# %%
p=1
a = int(input("enter a number"))
for i in range (1,a+1):
    p*=i
print(p)
# Out:
# enter a number 5
# 120
