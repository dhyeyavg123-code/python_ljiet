# %%
print("HELLO WORLD")
print("I AM DHYEY")
print("PYTHON")
# Out:
# HELLO WORLD
# I AM DHYEY
# PYTHON

# %%
print("HELLO WORLD \nI AM DHYEY \nPYTHON")
# Out:
# HELLO WORLD
# I AM DHYEY
# PYTHON

# %%
name = "DHYEY"
age = 18
ht = 5.7
status = True
print("my name is " , name , "\nmy age is " , age , "\nmy height is " , ht , "\nmy status is" , status)
print(f"my name is {name} \nmy age is {age} \nmy height is {ht} \nmy status is {status}")
# Out:
# my name is  DHYEY
# my age is  18
# my height is  5.7
# my status is True
# my name is DHYEY
# my age is 18
# my height is 5.7
# my status is True

# %%
a = 40
b = 3
print(f"sum of {a} and {b} is {a+b} \ndiff of {a} and {b} is {a-b} \nproduct of {a} and {b} is {a*b} \ndivision of {a} and {b} is {a/b} \nreminder of {a} and {b} is {a%b} \ndouble division of {a} and {b} is {a//b}")
# Out:
# sum of 40 and 3 is 43
# diff of 40 and 3 is 37
# product of 40 and 3 is 120
# division of 40 and 3 is 13.333333333333334
# reminder of 40 and 3 is 1
# double division of 40 and 3 is 13

# %%
a = int(input("enter a number"))
#b = int(input("enter a number"))
print()
# Out:
# enter a number 56
# enter a number 65
# 428767397726920461359949213083455469347901821842861057262916997345564317055935649863217467018497073282695955480576

# %%
r = float(input("enter the radius"))
x = 22/7
print(x * (r**2) , "units")
# Out:
# enter the radius 10
# 314.2857142857143 units
